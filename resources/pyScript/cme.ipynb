# %% [markdown]
# # Import Library #
# - pip install numpy
# - pip install matplotlib
# - pip install pandas

# %%
import numpy as np
import pandas as pd
import pymysql

# %% [markdown]
# ### Read Data ###

# %%
df = pd.read_excel('../Data Potensi CME Malang Juli 2024.xlsx')
df.head()
# Out:
#      id      divisi abbr_d wilayah abbr_w          sto abbr_s  \
# 0  2615  REGIONAL 5    TR5  MALANG     ML  MALANG KOTA    MLG
# 1  2616  REGIONAL 5    TR5  MALANG     ML  MALANG KOTA    MLG
# 2  2617  REGIONAL 5    TR5  MALANG     ML  MALANG KOTA    MLG
# 3  2618  REGIONAL 5    TR5  MALANG     ML  MALANG KOTA    MLG
# 4  2619  REGIONAL 5    TR5  MALANG     ML  MALANG KOTA    MLG
#
#               ruangan  kategori tipe_perangkat  ...      serial_number  \
# 0            R. MITRA  AC SPLIT       AC SPLIT  ...            E055728
# 1  R. BATTERY NEW NGN  AC SPLIT       AC SPLIT  ...  37366 7329 INDOOR
# 2  R. BATTERY NEW NGN  AC SPLIT       AC SPLIT  ...       373 663 8247
# 3             R. DWDM  AC SPLIT       AC SPLIT  ...                NaN
# 4               R.DDF  AC SPLIT       AC SPLIT  ...           E0019985
#
#    kap_tps  kap_tpk  satuan  kondisi   status periode   qrcode  keterangan  \
# 0  24000.0  24000.0    BTUH   NORMAL  OPERASI    2008  R503473       SPLIT
# 1  18000.0  18000.0    BTUH   NORMAL  OPERASI    2017  R502993       SPLIT
# 2  18000.0  18000.0    BTUH   NORMAL  OPERASI    2017  R503203       SPLIT
# 3  24000.0  24000.0    BTUH   NORMAL  OPERASI    2005  R503033       SPLIT
# 4  24000.0  24000.0    BTUH   NORMAL  OPERASI    2010  R502733       SPLIT
#
#              reg_date
# 0 2021-06-21 04:33:32
# 1 2021-06-21 04:33:32
# 2 2021-06-21 04:33:32
# 3 2021-06-21 04:33:32
# 4 2021-06-21 04:33:32
#
# [5 rows x 22 columns]

# %% [markdown]
# # Making Pivot #

# %%
category_counts = df.groupby(['sto', 'kategori']).size().reset_index(name='total')

# Pivot the table
pivot_table = category_counts.pivot_table(index='sto', columns='kategori', values='total', fill_value=0)

pivot_table = pivot_table.astype(int)

pivot_table['Total'] = pivot_table.sum(axis=1)
# Reset index to make 'sto' a column again
pivot_table = pivot_table.reset_index()


# pivot_table.head(15)

# %% [markdown]
# ## Sorting the year ##

# %% [markdown]
# #### Converting the Age ####

# %%
current_year=2024

df['age'] = current_year - df['periode']

# %% [markdown]
# #### Count the Number of Products in Each Age Range ####

# %%
bins = [0, 5, 10, df['age'].max()]
labels = ['underfive', 'morethanfive', 'morethanten']

# Create a new column in the DataFrame based on the conditions
df['age_range'] = pd.cut(df['age'], bins=bins, labels=labels, right=True)

# Group by 'sto' and 'age_range' and count occurrences
age_range_counts = df.groupby(['sto', 'age_range']).size().unstack(fill_value=0).reset_index()

print(age_range_counts)
# Out:
# age_range                   sto  underfive  morethanfive  morethanten
# 0                   AMPELGADING          3             1           26
# 1                        BANTUR          3             1           18
# 2                          BATU          4             2           24
# 3                      BLIMBING          4             4           27
# 4                        BURING          3             2           24
# 5                        DAMPIT          1             2           25
# 6                     DONOMULYO          2             1           20
# 7                        GADANG          3             3           22
# 8                  GONDANG LEGI          4             0           23
# 9                   GUNUNG KAWI          4             3           17
# 10                 KARANG PLOSO          2             1           24
# 11                     KEPANJEN          3             0           21
# 12                       KLOJEN          1             2           30
# 13                       LAWANG          5             0           19
# 14                  MALANG KOTA         10            28           45
# 15                     NGANTANG          1             0           17
# 16                        PAGAK          2             2           18
# 17                        PAKIS          1             0           17
# 18                    SAWOJAJAR          1             2           24
# 19                    SINGOSARI          1             0           24
# 20         SUMBER MANJING WETAN          3             1           19
# 21                SUMBER PUCUNG          4             1           18
# 22                      TUMPANG          2             0           17
# 23                        TUREN          2             0           19
# C:\Users\ryzen\AppData\Local\Temp\ipykernel_13144\4098047007.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_range_counts = df.groupby(['sto', 'age_range']).size().unstack(fill_value=0).reset_index()

# %% [markdown]
# ## Combining Tables ##

# %%
combined_df = pd.merge(pivot_table, age_range_counts, on='sto')

combined_df.head(40)
# Out:
#                      sto  AC PRESISI  AC SPLIT  BATTERE  CAPASITOR BANK  \
# 0            AMPELGADING           0         6        3               0
# 1                 BANTUR           0         4        4               0
# 2                   BATU           0         9        6               0
# 3               BLIMBING           0         6        8               1
# 4                 BURING           0         6        5               0
# 5                 DAMPIT           0         7        5               0
# 6              DONOMULYO           0         3        4               0
# 7                 GADANG           0         8        3               0
# 8           GONDANG LEGI           0         5        6               0
# 9            GUNUNG KAWI           0         3        4               0
# 10          KARANG PLOSO           0         7        4               0
# 11              KEPANJEN           0         7        5               0
# 12                KLOJEN           0         9        5               0
# 13                LAWANG           0         7        5               0
# 14           MALANG KOTA          10        19       13               1
# 15              NGANTANG           0         3        4               0
# 16                 PAGAK           0         4        3               0
# 17                 PAKIS           0         3        5               0
# 18             SAWOJAJAR           0         7        6               0
# 19             SINGOSARI           0         6        5               0
# 20  SUMBER MANJING WETAN           0         3        5               0
# 21         SUMBER PUCUNG           0         4        3               0
# 22               TUMPANG           0         5        4               0
# 23                 TUREN           0         4        4               0
#
#     DIESEL ENGINE / AMF  DIESEL MOBILE  GROUNDING  INSTALASI DAYA  INVERTER  \
# 0                     4              0          3              10         1
# 1                     4              0          3               3         1
# 2                     4              0          0               3         1
# 3                     6              0          1               4         1
# 4                     4              2          1               7         1
# 5                     6              0          2               3         1
# 6                     3              1          1               7         1
# 7                     7              0          1               5         1
# 8                     5              0          1               5         1
# 9                     4              0          1               8         1
# 10                    5              0          3               2         1
# 11                    4              0          0               4         1
# 12                    5              0          2               4         1
# 13                    4              0          0               3         0
# 14                    6              2          9              10         4
# 15                    4              0          1               2         1
# 16                    4              0          3               4         1
# 17                    4              0          0               2         1
# 18                    7              0          1               2         1
# 19                    3              0          0               7         1
# 20                    4              0          3               4         1
# 21                    3              0          1               8         1
# 22                    4              0          0               2         1
# 23                    5              0          1               3         1
#
#     OSASE  RECTIFIER  Total  underfive  morethanfive  morethanten
# 0       1          2     30          3             1           26
# 1       1          2     22          3             1           18
# 2       1          6     30          4             2           24
# 3       1          7     35          4             4           27
# 4       1          2     29          3             2           24
# 5       1          3     28          1             2           25
# 6       1          2     23          2             1           20
# 7       1          2     28          3             3           22
# 8       1          4     28          4             0           23
# 9       1          2     24          4             3           17
# 10      1          4     27          2             1           24
# 11      1          3     25          3             0           21
# 12      1          6     33          1             2           30
# 13      1          4     24          5             0           19
# 14      1          8     83         10            28           45
# 15      1          2     18          1             0           17
# 16      1          2     22          2             2           18
# 17      1          2     18          1             0           17
# 18      1          2     27          1             2           24
# 19      1          2     25          1             0           24
# 20      1          2     23          3             1           19
# 21      1          2     23          4             1           18
# 22      1          2     19          2             0           17
# 23      1          2     21          2             0           19

# %% [markdown]
# ### Importing To MySql ###

# %%
db_host = 'localhost'
db_user = 'root'
db_password = ''
db_name = 'arnet'

connection = pymysql.connect(
    host=db_host,
    user=db_user,
    password=db_password,
    database=db_name
)
sto = combined_df['sto'].unique()
sto = sorted(sto)
sto_mapping = {s: index + 1 for index, s in enumerate(sto)}

# Step 2: Apply the mapping to the DataFrame
combined_df['sto_id'] = combined_df['sto'].map(sto_mapping)

try:
    # Create a cursor object
    cursor = connection.cursor()
    
    # Truncate the table to clear existing data
    cursor.execute("TRUNCATE TABLE cmes")

    # Define the SQL INSERT stateme nt
    insert_query = """
    INSERT INTO cmes (sto_id, type_id, underfive, morethanfive, morethanten, total)
    VALUES (%s, %s, %s, %s, %s, %s)
    """

    # Iterate over the DataFrame rows and insert each row into the table
    for index, row in combined_df.iterrows():
        cursor.execute(insert_query, (
            row['sto_id'], 
            1,  # Assuming type_id is always 1
            row['underfive'],
            row['morethanfive'],
            row['morethanten'],
            row['Total']
        ))
        
    # Commit the transaction
    connection.commit()

finally:
    # Close the cursor and the connection
    cursor.close()
    connection.close()

print("Data inserted successfully")
# Out:
# Data inserted successfully

# %% [markdown]
# # This is for creating seeder only run if neccesery #

# %%
# Get unique values of 'sto', 'ruangan', and 'kategori' columns
sto = df['sto'].unique()
sto = sorted(sto)
rooms = df['ruangan'].unique()
category = df['kategori'].unique()

# Prepare the data for seeder
dropdowns = {}

# Create a dictionary with 'sto' values
for index, s in enumerate(sto):
    dropdowns[str(index)] = { 
        'type': ['sto'],
        'subtype': [s]
    }

# Create a dictionary with 'room' values starting from len(sto)
start_index = len(sto)
for index, room in enumerate(rooms):
    dropdowns[str(start_index + index)] = {  
        'type': ['room'],
        'subtype': [room]
    }

# Create a dictionary with 'category' values starting from len(sto) + len(rooms)
start_index = len(sto) + len(rooms)
for index, c in enumerate(category):
    dropdowns[str(start_index + index)] = {  
        'type': ['category'],
        'subtype': [c]
    }

# Convert the dictionary to PHP-like array syntax
def dict_to_php_array(d):
    php_array = "{\n"
    for key, value in d.items():
        php_array += f"    '{key}' => [\n"
        php_array += f"        'type' => {value['type']},\n"
        php_array += f"        'subtype' => {value['subtype']},\n"
        php_array += "    ],\n"
    php_array += "}\n"
    return php_array

php_array_str = dict_to_php_array(dropdowns)
print(php_array_str)
# Out:
# {
#     '0' => [
#         'type' => ['sto'],
#         'subtype' => ['AMPELGADING'],
#     ],
#     '1' => [
#         'type' => ['sto'],
#         'subtype' => ['BANTUR'],
#     ],
#     '2' => [
#         'type' => ['sto'],
#         'subtype' => ['BATU'],
#     ],
#     '3' => [
#         'type' => ['sto'],
#         'subtype' => ['BLIMBING'],
#     ],
#     '4' => [
#         'type' => ['sto'],
#         'subtype' => ['BURING'],
#     ],
#     '5' => [
#         'type' => ['sto'],
#         'subtype' => ['DAMPIT'],
#     ],
#     '6' => [
#         'type' => ['sto'],
#         'subtype' => ['DONOMULYO'],
#     ],
#     '7' => [
#         'type' => ['sto'],
#         'subtype' => ['GADANG'],
#     ],
#     '8' => [
#         'type' => ['sto'],
#         'subtype' => ['GONDANG LEGI'],
#     ],
#     '9' => [
#         'type' => ['sto'],
#         'subtype' => ['GUNUNG KAWI'],
#     ],
#     '10' => [
#         'type' => ['sto'],
#         'subtype' => ['KARANG PLOSO'],
#     ],
#     '11' => [
#         'type' => ['sto'],
#         'subtype' => ['KEPANJEN'],
#     ],
#     '12' => [
#         'type' => ['sto'],
#         'subtype' => ['KLOJEN'],
#     ],
#     '13' => [
#         'type' => ['sto'],
#         'subtype' => ['LAWANG'],
#     ],
#     '14' => [
#         'type' => ['sto'],
#         'subtype' => ['MALANG KOTA'],
#     ],
#     '15' => [
#         'type' => ['sto'],
#         'subtype' => ['NGANTANG'],
#     ],
#     '16' => [
#         'type' => ['sto'],
#         'subtype' => ['PAGAK'],
#     ],
#     '17' => [
#         'type' => ['sto'],
#         'subtype' => ['PAKIS'],
#     ],
#     '18' => [
#         'type' => ['sto'],
#         'subtype' => ['SAWOJAJAR'],
#     ],
#     '19' => [
#         'type' => ['sto'],
#         'subtype' => ['SINGOSARI'],
#     ],
#     '20' => [
#         'type' => ['sto'],
#         'subtype' => ['SUMBER MANJING WETAN'],
#     ],
#     '21' => [
#         'type' => ['sto'],
#         'subtype' => ['SUMBER PUCUNG'],
#     ],
#     '22' => [
#         'type' => ['sto'],
#         'subtype' => ['TUMPANG'],
#     ],
#     '23' => [
#         'type' => ['sto'],
#         'subtype' => ['TUREN'],
#     ],
#     '24' => [
#         'type' => ['room'],
#         'subtype' => ['R. MITRA'],
#     ],
#     '25' => [
#         'type' => ['room'],
#         'subtype' => ['R. BATTERY NEW NGN'],
#     ],
#     '26' => [
#         'type' => ['room'],
#         'subtype' => ['R. DWDM'],
#     ],
#     '27' => [
#         'type' => ['room'],
#         'subtype' => ['R.DDF'],
#     ],
#     '28' => [
#         'type' => ['room'],
#         'subtype' => ['R. DIESEL'],
#     ],
#     '29' => [
#         'type' => ['room'],
#         'subtype' => ['R. RECTI BENING'],
#     ],
#     '30' => [
#         'type' => ['room'],
#         'subtype' => ['R. AULA BESAR'],
#     ],
#     '31' => [
#         'type' => ['room'],
#         'subtype' => ['R. NEW NGN'],
#     ],
#     '32' => [
#         'type' => ['room'],
#         'subtype' => ['R. NGN OLD'],
#     ],
#     '33' => [
#         'type' => ['room'],
#         'subtype' => ['R. BATTERY BAWAH'],
#     ],
#     '34' => [
#         'type' => ['room'],
#         'subtype' => ['R. MDP DIESEL'],
#     ],
#     '35' => [
#         'type' => ['room'],
#         'subtype' => ['TOWER'],
#     ],
#     '36' => [
#         'type' => ['room'],
#         'subtype' => ['R. PERSONIL SKSO'],
#     ],
#     '37' => [
#         'type' => ['room'],
#         'subtype' => ['R. DDF'],
#     ],
#     '38' => [
#         'type' => ['room'],
#         'subtype' => ['AREA PARKIR'],
#     ],
#     '39' => [
#         'type' => ['room'],
#         'subtype' => ['SAMPING GEDUNG'],
#     ],
#     '40' => [
#         'type' => ['room'],
#         'subtype' => ['R. MAC LT.2'],
#     ],
#     '41' => [
#         'type' => ['room'],
#         'subtype' => ['R. RECTI BAWAH'],
#     ],
#     '42' => [
#         'type' => ['room'],
#         'subtype' => ['R.TRANSMISI'],
#     ],
#     '43' => [
#         'type' => ['room'],
#         'subtype' => ['LORONG STO AMP'],
#     ],
#     '44' => [
#         'type' => ['room'],
#         'subtype' => ['R.BATERAY'],
#     ],
#     '45' => [
#         'type' => ['room'],
#         'subtype' => ['R.RECTIFIER'],
#     ],
#     '46' => [
#         'type' => ['room'],
#         'subtype' => ['R.EXSENTRAL'],
#     ],
#     '47' => [
#         'type' => ['room'],
#         'subtype' => ['R.GENSET'],
#     ],
#     '48' => [
#         'type' => ['room'],
#         'subtype' => ['R.BATTERY'],
#     ],
#     '49' => [
#         'type' => ['room'],
#         'subtype' => ['POS SECURITY'],
#     ],
#     '50' => [
#         'type' => ['room'],
#         'subtype' => ['TOWER AREA'],
#     ],
#     '51' => [
#         'type' => ['room'],
#         'subtype' => ['PINTU PAGAR'],
#     ],
#     '52' => [
#         'type' => ['room'],
#         'subtype' => ['R. SENTRAL'],
#     ],
#     '53' => [
#         'type' => ['room'],
#         'subtype' => ['R. TRANSMISI'],
#     ],
#     '54' => [
#         'type' => ['room'],
#         'subtype' => ['R. BATTERY'],
#     ],
#     '55' => [
#         'type' => ['room'],
#         'subtype' => ['R. JANM'],
#     ],
#     '56' => [
#         'type' => ['room'],
#         'subtype' => ['R. RECTIFIER'],
#     ],
#     '57' => [
#         'type' => ['room'],
#         'subtype' => ['R.LANTAI 2'],
#     ],
#     '58' => [
#         'type' => ['room'],
#         'subtype' => ['R.MDP'],
#     ],
#     '59' => [
#         'type' => ['room'],
#         'subtype' => ['GEDUNG STO BURING'],
#     ],
#     '60' => [
#         'type' => ['room'],
#         'subtype' => ['R.DIESEL'],
#     ],
#     '61' => [
#         'type' => ['room'],
#         'subtype' => ['R.SENTRAL'],
#     ],
#     '62' => [
#         'type' => ['room'],
#         'subtype' => ['R.EKS SENTRAL'],
#     ],
#     '63' => [
#         'type' => ['room'],
#         'subtype' => ['R. GENSET'],
#     ],
#     '64' => [
#         'type' => ['room'],
#         'subtype' => ['R. SAMPING TANDON BBM'],
#     ],
#     '65' => [
#         'type' => ['room'],
#         'subtype' => ['R.MDF'],
#     ],
#     '66' => [
#         'type' => ['room'],
#         'subtype' => ['R.SENTRAL/METRO'],
#     ],
#     '67' => [
#         'type' => ['room'],
#         'subtype' => ['R BATTERY'],
#     ],
#     '68' => [
#         'type' => ['room'],
#         'subtype' => ['BAWAH TOWER'],
#     ],
#     '69' => [
#         'type' => ['room'],
#         'subtype' => ['DEPAN GUDANG TA'],
#     ],
#     '70' => [
#         'type' => ['room'],
#         'subtype' => ['SAMPING RUANG SENTRAL'],
#     ],
#     '71' => [
#         'type' => ['room'],
#         'subtype' => ['R.GPON'],
#     ],
#     '72' => [
#         'type' => ['room'],
#         'subtype' => ['TAMAN'],
#     ],
#     '73' => [
#         'type' => ['room'],
#         'subtype' => ['LORONG LT.2'],
#     ],
#     '74' => [
#         'type' => ['room'],
#         'subtype' => ['AREA TOWER'],
#     ],
#     '75' => [
#         'type' => ['room'],
#         'subtype' => ['R.DISEL'],
#     ],
#     '76' => [
#         'type' => ['room'],
#         'subtype' => ['R. FTM'],
#     ],
#     '77' => [
#         'type' => ['category'],
#         'subtype' => ['AC SPLIT'],
#     ],
#     '78' => [
#         'type' => ['category'],
#         'subtype' => ['AC PRESISI'],
#     ],
#     '79' => [
#         'type' => ['category'],
#         'subtype' => ['BATTERE'],
#     ],
#     '80' => [
#         'type' => ['category'],
#         'subtype' => ['DIESEL ENGINE / AMF'],
#     ],
#     '81' => [
#         'type' => ['category'],
#         'subtype' => ['RECTIFIER'],
#     ],
#     '82' => [
#         'type' => ['category'],
#         'subtype' => ['INSTALASI DAYA'],
#     ],
#     '83' => [
#         'type' => ['category'],
#         'subtype' => ['OSASE'],
#     ],
#     '84' => [
#         'type' => ['category'],
#         'subtype' => ['GROUNDING'],
#     ],
#     '85' => [
#         'type' => ['category'],
#         'subtype' => ['INVERTER'],
#     ],
#     '86' => [
#         'type' => ['category'],
#         'subtype' => ['CAPASITOR BANK'],
#     ],
#     '87' => [
#         'type' => ['category'],
#         'subtype' => ['DIESEL MOBILE'],
#     ],
# }
